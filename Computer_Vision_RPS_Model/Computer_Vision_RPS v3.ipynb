# %% [markdown]
# ## Computer-Vision-Project: Rock Paper Scissors

# %% [markdown]
# ## Create the Rock, Paper, Scissors Game

# %%
from random import choice
import time
import cv2
from tensorflow.keras.models import load_model
import numpy as np

class RPS_Game():     
      def __init__(self):
            self.name = ''
            self.player_choice = ''
            self.computer_choice = ''
            self.computer_wins = 0
            self.player_wins = 0
            self.options = ['Rock', 'Paper','Scissors']
            self.rounds = 0
            self.putText = ''
            
            
      
      
      # Move Lookup for Camera selection
      def move_list(self, value):
            Rev_Class_Map = {
                  0: 'Rock',
                  1: 'Paper',
                  2: 'Scissors',
                  3: 'Nothing'
            }
            return Rev_Class_Map[value]
      
      #Make a Prediction from the frame given
      def make_a_prediction(self, frame, data, model):
            ret, frame = cap.read()
            resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
            image_np = np.array(resized_frame)
            normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
            data[0] = normalized_image
            prediction = model.predict(data)
            prediction = np.argmax(prediction[:5])
            self.player_choice = self.move_list(prediction)
            print(f'{self.name} choice is {self.player_choice}')
            if self.player_choice != 'Nothing' and self.player_choice != 'None':
                  ret, frame = cap.read()
                  self.show_text(frame, f"{self.name}'s move: {self.player_choice}", (50,75), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2, cv2.LINE_4)
                  cv2.waitKey(500)
                  cv2.imshow('Rock, Paper, Scissors Game', frame)
                  self.get_computer_choice()
            else:
                  self.getting_started()
            
            
      def welcome(self):
            print("Welcome to my Computer Vision Project in which you will play the classic game of Rock, Paper, Scissors")
            self.name = input("Please enter you name for the game")
            print('Hello,', self.name)
          
            
      
      def getting_started(self):
            ret, frame = cap.read()
            #Starting the game
            if self.player_wins == 0 and self.computer_wins == 0:
                self.show_text(frame, 'Press S to start the game or Q to quit', (50, 225),  cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2, cv2.LINE_AA)
                pressKey = cv2.waitKey(1) & 0xFF
                if pressKey == ord('q'):
                        self.show_text(frame, 'Thanks for playing', (200, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_4)
                        cv2.waitKey(250)
                        cap.release()
                        cv2.destroyAllWindows()       
                  

                elif pressKey == ord('s'):
                        previous = time.time()
                        TIMER  = 3
                        while TIMER > 0:
                              self.show_text(frame, f'Select Rock, Paper, Scissors:{TIMER}',(50, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)         
                              cv2.waitKey(125)


                                    #Countdown
                              current = time.time()
                              if current - previous >= 1:
                                    previous = current
                                    TIMER = TIMER - 1
                        
                              else:                           
                                    self.make_a_prediction(frame, data, model)
                                
            elif self.player_wins < 3 or self.computer_wins <  3:
                  self.show_text(frame, 'Press C to continue to next round or Q to quit', (10, 250),  cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2, cv2.LINE_AA)
                  pressKey = cv2.waitKey(1) & 0xFF
                  if pressKey == ord('q'):
                        self.show_text(frame, 'Thanks for playing', (200, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_4)
                        cv2.waitKey(250)
                        cap.release()
                        cv2.destroyAllWindows()
                  

                  elif pressKey == ord('c'):
                        previous = time.time()
                        TIMER  = 3
                        while TIMER > 0:
                              self.show_text(frame, f'Select Rock, Paper, Scissors:{TIMER}',(50, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)        
                              cv2.waitKey(125)


                              #Countdown
                              current = time.time()
                              if current - previous >= 1:
                                    previous = current
                                    TIMER = TIMER - 1

                              else: 
                                    self.make_a_prediction(frame, data, model)

            elif self.player_wins == 3 or self.computer_wins == 3:
                pressKey = cv2.waitKey(1) & 0xFF
                self.show_text(frame, 'Press P to play again or Q to end game', (10, 225),  cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2, cv2.LINE_AA)
                if pressKey == ord('q'):
                    self.show_text(frame, 'Thanks for playing', (200, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_4)
                    cv2.waitKey(250)
                    camera = False
                    # After the loop release the cap object
                    cap.release()
                    # Destroy all the windows
                    cv2.destroyAllWindows()

                elif pressKey == ord('p'):
                    self.computer_wins = 0
                    self.player_wins = 0
                    self.getting_started() 
            
          
            
           
                 
      def get_computer_choice(self):
            #Computer Choice for Game
            ret, frame = cap.read()
            cv2.rectangle(frame, (800, 100), (1200, 500), (255, 255, 255), 2)
            self.computer_choice = choice(self.options)
            print(f'The Computer chooses {self.computer_choice}')
            # Shows a picture of the Computer's move
            if self.computer_choice != 'None':
                  icon = cv2.imread(
                  "images/{}.png".format(self.computer_choice))
                  icon = cv2.resize(icon, (400,400))
                  image_np = np.array(icon)
                  normalized_icon = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
                  cv2.imshow('RPS Game: Computer Choice', icon)
      
            self.show_text(icon, f"Computer's move: {self.computer_choice}", (400,75), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2, cv2.LINE_4)
            cv2.waitKey(500)
            cv2.imshow('Rock, Paper, Scissors Game', frame)
            self.who_wins()
          
      def who_wins(self):
            if self.player_wins < 3 and self.computer_wins < 3 :
                 if self.computer_choice == self.player_choice:
                        print("It's a tie")
                        self.show_text(frame, f"It's a Tie ", (100, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8)
                        self.rounds +=1
                        cv2.waitKey(250)
                        self.play_again()

                 elif self.player_choice == ('Rock'):
                        if self.computer_choice == 'Paper':
                              self.computer_wins += 1
                              print('The computer wins')
                              self.show_text(frame, f"The Computer Wins!!", (75, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8) 
                              self.rounds +=1
                              cv2.waitKey(500)
                              self.play_again()
                        elif self.computer_choice == 'Scissors':
                              self.player_wins +=1
                              self.rounds +=1
                              print(f'{self.name} wins!')
                              self.show_text(frame, f"{self.name} Wins!!", (100, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8)
                              cv2.waitKey(500)
                              self.play_again()
                 elif self.player_choice == 'Paper':
                        if self.computer_choice == 'Scissors':
                              self.computer_wins += 1
                              self.rounds +=1
                              print('The computer wins')
                              self.show_text(frame, f"The Computer Wins!!", (75, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8)  
                              cv2.waitKey(500)
                              self.play_again()
                        elif self.computer_choice == 'Rock':
                              self.player_wins += 1
                              self.rounds +=1
                              print(f'{self.name} wins!')
                              self.show_text(frame, f"{self.name} Wins!!", (100, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8) 
                              cv2.waitKey(500)
                              self.play_again()
                 elif self.player_choice == 'Scissors':
                        if self.computer_choice == 'Paper':
                              self.player_wins += 1
                              self.rounds +=1
                              print(f'{self.name} wins!')
                              self.show_text(frame, f"{self.name} Wins!!", (100, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8)
                              cv2.waitKey(500)
                              self.play_again()
                        elif self.computer_choice == 'Rock':
                              self.computer_wins += 1
                              self.rounds +=1
                              print('The computer wins')
                              self.show_text(frame, f"The Computer Wins!!", (75, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 255), 2, cv2.LINE_8)
                              cv2.waitKey(500)
                              self.play_again()    
                  
                       
       #Determines when the game is over     
      def play_again(self):
            ret, frame = cap.read()
            pressKey = cv2.waitKey(1) & 0xFF
            if self.computer_wins == 3 or self.player_wins == 3:
                  
                  if self.computer_wins == 3:
                        cv2.putText(frame, f"The Computer Wins!!", (50, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 255, 255), 2, cv2.LINE_AA)
                        print('The Computer WINS!!')
            
                  elif self.player_wins == 3:
                        cv2.putText(frame, f'{self.name} WINS!!', (50, 250), cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 255, 255), 2, cv2.LINE_AA)
                        print(f'{self.name} WINS!!')
               
                              
            else:
                  self.player_choice = ''
                  self.computer_choice = ''
                  self.getting_started()
                              
      
  
      def show_text(self, frame, text, text_position, font, fontsize, color, thickness, linetype):
            ret, frame = cap.read()
            cv2.putText(frame, text, text_position, font, fontsize, (0, 255, 255),thickness,cv2.LINE_AA)
            cv2.putText(frame, f'{self.name}:' + str(self.player_wins), (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_4)
            cv2.putText(frame, f'Computer Wins:' + str(self.computer_wins), (400, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_4)
            cv2.putText(frame, f'Rounds:' + str(self.rounds), (250, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2, cv2.LINE_4)
            cv2.putText(frame, f"{self.name}'s move: {self.player_choice}", (50,75), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2, cv2.LINE_4)
            cv2.putText(frame, f"Computer's move: {self.computer_choice}", (400,75), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2, cv2.LINE_4)
            cv2.imshow('Rock, Paper, Scissors Game', frame)
            # cv2.putText(frame, , (150,50), 1, (0, 0, 0), 2, cv2.LINE_4)
            # cv2.putText(frame, f'Rounds' + str(self.rounds), (100,50), 1, (0, 0, 0), 2, cv2.LINE_4)
            
model = load_model('RPS_Model_Final.h5')
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
new_RPS_game = RPS_Game()
new_RPS_game.welcome()

            
while True: 
      ret, frame = cap.read()
      resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
      image_np = np.array(resized_frame)
      normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
      data[0] = normalized_image
      prediction = model.predict(data)
      cv2.imshow('Rock, Paper, Scissors Game', frame)
      new_RPS_game.getting_started()
      if cv2.waitKey(1) & 0xFF == ord('q'):
            break
                        
cap.release()
cv2.destroyAllWindows()
# Out:
# 2022-05-05 03:12:41.828051: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-05 03:12:41.828322: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-05 03:12:41.829803: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Welcome to my Computer Vision Project in which you will play the classic game of Rock, Paper, Scissors
# Hello, Jazzmin
# 2022-05-05 03:12:48.362816: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-05-05 03:12:48.382166: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2395320000 Hz
# Qt: Session management error: Could not open network socket
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# Jazzmin choice is Nothing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS v3.ipynb Cell 3' in <cell line: 255>()
#     <a href='vscode-notebook-cell:/home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS%20v3.ipynb#ch0000003?line=257'>258</a> normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#     <a href='vscode-notebook-cell:/home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS%20v3.ipynb#ch0000003?line=258'>259</a> data[0] = normalized_image
# --> <a href='vscode-notebook-cell:/home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS%20v3.ipynb#ch0000003?line=259'>260</a> prediction = model.predict(data)
#     <a href='vscode-notebook-cell:/home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS%20v3.ipynb#ch0000003?line=260'>261</a> cv2.imshow('Rock, Paper, Scissors Game', frame)
#     <a href='vscode-notebook-cell:/home/jazzy/Documents/AiCore/AiCore_Projects/Computer_Vision_Rock_Paper_Scissors/Computer-Vision-Project/Computer_Vision_RPS_Model/Computer_Vision_RPS%20v3.ipynb#ch0000003?line=261'>262</a> new_RPS_game.getting_started()
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1625, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=1622'>1623</a> callbacks.on_predict_begin()
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=1623'>1624</a> batch_outputs = None
# -> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=1624'>1625</a> for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=1625'>1626</a>   with data_handler.catch_stop_iteration():
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py?line=1626'>1627</a>     for step in data_handler.steps():
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1133, in DataHandler.enumerate_epochs(self)
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=1130'>1131</a> """Yields `(epoch, tf.data.Iterator)`."""
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=1131'>1132</a> with self._truncate_execution_to_epoch():
# -> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=1132'>1133</a>   data_iterator = iter(self._dataset)
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=1133'>1134</a>   for epoch in range(self._initial_epoch, self._epochs):
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py?line=1134'>1135</a>     if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:422, in DatasetV2.__iter__(self)
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=419'>420</a> if context.executing_eagerly() or ops.inside_function():
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=420'>421</a>   with ops.colocate_with(self._variant_tensor):
# --> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=421'>422</a>     return iterator_ops.OwnedIterator(self)
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=422'>423</a> else:
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=423'>424</a>   raise RuntimeError("__iter__() is only supported inside of tf.function "
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=424'>425</a>                      "or when eager execution is enabled.")
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:682, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=679'>680</a> if (components is not None or element_spec is not None):
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=680'>681</a>   raise ValueError(error_message)
# --> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=681'>682</a> self._create_iterator(dataset)
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:705, in OwnedIterator._create_iterator(self, dataset)
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=699'>700</a> with ops.colocate_with(ds_variant):
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=700'>701</a>   self._iterator_resource, self._deleter = (
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=701'>702</a>       gen_dataset_ops.anonymous_iterator_v2(
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=702'>703</a>           output_types=self._flat_output_types,
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=703'>704</a>           output_shapes=self._flat_output_shapes))
# --> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=704'>705</a>   gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=705'>706</a>   # Delete the resource when this object is deleted
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=706'>707</a>   self._resource_deleter = IteratorResourceDeleter(
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=707'>708</a>       handle=self._iterator_resource,
#     <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py?line=708'>709</a>       deleter=self._deleter)
#
# File ~/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:2971, in make_iterator(dataset, iterator, name)
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2968'>2969</a> if tld.is_eager:
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2969'>2970</a>   try:
# -> <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2970'>2971</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2971'>2972</a>       _ctx, "MakeIterator", name, dataset, iterator)
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2972'>2973</a>     return _result
#    <a href='file:///home/jazzy/miniconda3/envs/Computer_Vision_RPS/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py?line=2973'>2974</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
